# %% [markdown]
# <div align="center"> <h3><font color='cyan'>CSE 574 Section D: Introduction to Machine Learning, Fall 2025 </font>
# <h1> Assignment 0: Python Skills for ML
#
# <h3>Checkpoint: September 4, Thu, 11:59pm
# <h2><font color='red'>Final Due Date: </font> September 11, Thu, 11:59pm</div>
#
# Welcome to your first CSE 574 assignment! The goal of this assignment is to sharpen your programming skills needed for this class. It is focused on familiarizing yourself with Python and main data science libraries that will be used for other assignments as well.
#
# There are a total of six parts. We will focus on basic Python functions, explore numpy, pandas, matplotlib, scikit-learn libraries,  and analyze the real-world dataset.
#
# If you are new to Python, check our [Python resources page](https://ubuffalo-my.sharepoint.com/:w:/g/personal/avereshc_buffalo_edu/Eet_1to5aBZPuIxlNzEseOMBqR_eA4I7p1LYAaRBDMGmtw?e=lUvbeg).
#
#
# ### Submission
#
# All the details you need for this assignment are located within this notebook. You are expected to follow every block and complete the task within the marks ``` # BEGIN_YOUR_CODE ``` and ```# END_YOUR_CODE```. Do not modify or edit code beyond these lines. You can add helper functions in the new cells, if needed. We recommend completing the task within this .ipynb notebook, if needed you can convert it and submit as .py script. Try to make your code as clean and simple as possible and be sure to write your answers between the begin answer and end answer comments.
#
# 1. Submit at **Brighspace > Assesments > Assignments**
# 2. The code of your implementations should be written in Python
# 3. For each "Reflection" question, add your reasoning for 1-2 sentences as Python comment in the related block
# 3. All project files should be submitted as jupyter notebooks named UBIT_assignment0_checkpoint.ipynb or UBIT_assignment0_final.ipynb, e.g. avereshc_assignment0_checkpoint.ipynb or avereshc_assignment0_final.ipynb.
# 4. Please submit a .ipynb file only. Submitions with .py, .json, .pdf or any other type won't be considered for evaluation. Your Jupyter notebook should be saved with the results.
# 5. Include all the references that have been used to complete the assignment.
#
# ### Checkpoint Submission <font color='red'>[Due Date: Sep 4]</font>
# Complete Part 1, Part 2 and submit the code in the .ipynb file named UBIT_assignment0_checkpoint.ipynb. Checkpoint will be evaluated after the final submission.
#
# ### Final Submission <font color='red'>[Due Date: Sep 11]</font>
# Complete all parts of the assignment and submit the code in the .ipynb file named UBIT_assignment0_final.ipynb. You may add slight modification to your Checkpoint submission if needed.
#
# **Assignment Outline**
#
# | Part | Description | # of tasks | Points |
# | --- | --- | --- | --- |
# | [Part 1](#part1) | Python & Numpy Basics | 21 | 25 |
# | [Part 2](#part2) | Algorithms | 2 | 10 |
# | [Part 3](#part3) | Pandas Basics | 10 | 15 |
# | [Part 4](#part4) | Matplotlib Basics | 5 | 20 |
# | [Part 5](#part5) | Scikit Learn Basics | 3 | 20 |
# | [Part 6](#part6) | Optuna Basics | 2 | 10 |
# | [References](#references) | Include all the references used |
#
#
# ### Academic Integrity
#
# This task must be completed individually.
# The standing policy of the Department is that all students involved in any academic integrity violation (e.g. plagiarism in any way, shape, or form) will receive an F grade for the course. The catalog describes plagiarism as “Copying or receiving material from any source and submitting that material as one’s own, without acknowledging and citing the particular debts to the source, or in any other manner representing the work of another as one’s own.”. Refer to the [Office of Academic Integrity](https://www.buffalo.edu/academic-integrity.html) for more details.
#
#
# ### Late Days Policy
# You can use up to 7 late days throughout the course toward any programming taks, assignments' checkpoint or final submission. You do not have to inform the instructor, as the late submission will be tracked in UBlearns.
#
# ### FAQ
# >What does 'raise Exception("Not implemented yet")' mean?
#
# Here we define a custom exception to highlight that the task is not implemented yet. Once you implement your code, ensure to remove this part.
#
# >Can I add code beyond # BEGIN_YOUR_CODE parts.
#
# Yes, you can add helper functions. Add them in the separate cell with the comments, why you need it

# %% [markdown]
# <a id='part1'></a>
# ## Part 1: Python and Numpy Basics [20 Points]
#
# > **Academic Integrity Reminder:**
# > Do not use AI chat, auto-generated solutions for these exercises or your friends' solutions. The goal is to refresh your own coding fluency. Try solving each task step by step, even if it feels repetitive, this practice builds the foundation you'll need for more advanced ML coding later.

# %% [markdown]
# The first part of this assignment gives you practice with python syntax. Follow the cells below for the instructions.

# %% [markdown]
# 1. Hello UB
#
# Write a function that will print a phrase "Hello UB! " 101 times
#
# Expected Output: "Hello UB! Hello UB! Hello UB! Hello UB! Hello UB! ..."

# %%
# BEGIN_YOUR_CODE
def func_to_print_UB():
    valueToBePrinted = "Hello UB!"
    print(valueToBePrinted*100)

func_to_print_UB()
# END_YOUR_CODE
# Out:
# Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!Hello UB!

# %% [markdown]
# 2. Adding elements with validation
#
# - Create an empty list.
# - Add five of your favorite holiday destinations to the list **using `input()` and `append()`**.
# - Ignore empty strings (if the user presses enter without typing).
# - Finally, print the list lexicographically sorted.
#
# Example:
# ```
# Input: Paris, Tokyo, , London, Rome, New York
# Output: ['London', 'New York', 'Paris', 'Rome', 'Tokyo']
# ```

# %%
# BEGIN_YOUR_CODE
emptyList =[]
for i in range(5):
    x = input("Enter the holiday destination: ")
    if(x!=""):
        emptyList.append(x)
emptyList.sort()
print(emptyList)
# END_YOUR_CODE
# Out:
# Enter the holiday destination: London
# Enter the holiday destination: Paris
# Enter the holiday destination: Tokyo
# Enter the holiday destination: New york
# Enter the holiday destination:
# ['London', 'New york', 'Paris', 'Tokyo']

# %% [markdown]
# 3. Even squares and add cubes
#
# Given a list of integers, replace:
#
# - Every even number with its square.
# - Every odd number with its cube.
#
# Print the updated list.
#
# Example:
#
# ```python
# Input: [0, 1, 2, 3, 4, 5]
# Output: [0, 1, 4, 27, 16, 125]
# ```
#
# Reflection: What happens if you pass negative numbers into your function?

# %%
# BEGIN_YOUR_CODE
def OddOrEven(a):
    updatedList = []
    for i in range(len(a)):
        if (a[i]%2==0):
            updatedList.append(a[i]*a[i])
        elif(a[i]%2==1):
            updatedList.append(a[i]*a[i]*a[i])
        else:
            print("Not a valid number")
    print(updatedList)

a = [0,-1,2,3,-4,-5]
OddOrEven(a)
# END_YOUR_CODE

'''
Reflection
Ans -> If i'm passing negative values to the function, we are still able to check whether
the number is even or odd and based on the square or cube the sign values differ between [+,-]
Therefore the function is still being applicable for negative numbers
# Out:
# [0, -1, 4, 27, 16, -125]

# %% [markdown]
# 4. Counting occurrences
#
# Write a function that counts the number of times a given word appears in a sentence.
#
# The word should be matched as a whole word, and the search should be case-insensitive.
#
# For example: "The book is on the table", total occurances of "the" is 2.
#
# Reflection: Why is case-insensitive matching often needed in text processing?

# %%
# BEGIN_YOUR_CODE
def fun_to_count_occurences(sentence,word_to_count):
    '''
    Previous code submitted as part of checkpoint 0
    upperstring = sentence.upper()
    wordtocountupperstring = word_to_count.upper()
    cnt = upperstring.count(wordtocountupperstring)
    print(cnt)
    '''
    wordlower = sentence.lower()
    wordsplit = wordlower.split()
    cnt= wordsplit.count(word_to_count.lower())
    print('Count: \n',cnt)
sentence = "The cat and the dog played in the park next to the theater. The cat was happy."
word_to_count = "the"
fun_to_count_occurences(sentence,word_to_count)
# END_YOUR_CODE

'''
#Reflection
Ans -> It is often observed that while extracting features from a text,
words would be of the same meaning however if we store it,
as different words, mainly it leads to the increase of space and might overall consider it
as a different feature which is not the case and moreover incase if you're using
the words later on to feed to a model ,it would be training on two different labels
with the same meaning rather than one
'''
# Out:
# Count:
#  5
# "\n#Reflection\nAns -> It is often observed that while extracting features from a text,\nwords would be of the same meaning however if we store it,\nas different words, mainly it leads to the increase of space and might overall consider it\nas a different feature which is not the case and moreover incase if you're using\nthe words later on to feed to a model ,it would be training on two different labels\nwith the same meaning rather than one\n"

# %% [markdown]
# 5. Pattern
#
# Create a function that generates and prints a specific number pattern based on the input integer n.
# The pattern consists of rows where each row contains consecutive multiples of the row number. Take an input n from user.
#
# Example Output:
#
# For 'n = 3', the pattern will be:
# 1
# 2 4
# 3 6 9
#
# For 'n = 6', the pattern will be:
# 1
# 2 4
# 3 6 9
# 4 8 12 16
# 5 10 15 20 25
# 6 12 18 24 30 36
#
# Only submissions with a written function that will encode this exact pattern will be considered for evaluation

# %%
def funToCount_Consecutive_Multiples(val):
    ncnt = val+1
    list = []
    list.append(1)
  #  print('List: ', list)
  #  print('Value of ncnt: ',ncnt)
    for i in range(2,ncnt):
        j = 1
        sum = 0
        while(j<=i):
            sum = sum +i
            list.append(sum)
            j = j+1
    print('Final List: ', list)

if __name__ == '__main__':
    x = input('Enter the value of n: ')
    val = int(x)
   # print(type(val))
    funToCount_Consecutive_Multiples(val)
# Out:
# Enter the value of n: 5
# Final List:  [1, 2, 4, 3, 6, 9, 4, 8, 12, 16, 5, 10, 15, 20, 25]

# %% [markdown]
# 6. Reversing
#
# Reverse the order of elements in a list given below, so the expected output is as follows: ['Avengers', 'Age of Ultron', 'Infinity War', 'Endgame']
# Print the reversed list.

# %%
list1 = ["Endgame", "Infinity War", "Age of Ultron", "Avengers"]

# BEGIN_YOUR_CODE
reversedlist = list1[::-1]
print('Reversed List: \n',reversedlist)
# END_YOUR_CODE
# Out:
# Reversed List:
#  ['Avengers', 'Age of Ultron', 'Infinity War', 'Endgame']

# %% [markdown]
# 7. Numbering a list
#
# Write a function that will return a numbered list of the famous actors whose name starts from 'C' using "enumerate()" function.
# Print the numbered list
#
# Expected output:
# 1. Christian Bale
# 2. Chris Evans
# 3. Chris Hemsworth
# 4. Cate Blanchett

# %%
actors = ['Margot Robbie', 'Christian Bale', 'Ryan Gosling', 'Chris Evans', 'Chris Hemsworth', 'Cate Blanchett']

# BEGIN_YOUR_CODE
x = []
for i in range(len(actors)):
    if(actors[i].startswith("C")):
        x.append(actors[i]);

for index, actor in enumerate(x, start=1):
  print(index, actor, sep=". ")

# print(list(new_list))
# END_YOUR_CODE
# Out:
# 1. Christian Bale
# 2. Chris Evans
# 3. Chris Hemsworth
# 4. Cate Blanchett

# %% [markdown]
# 8. Combining lists
#
# Combine two lists given below using zip() function and print out the result
# Print the combined list

# %%
actors = ['Robert Downey Jr.', 'Scarlett Johansson', 'Chris Evans', 'Chris Hemsworth', 'Mark Ruffalo','Dummy']
role = ['Iron Man', 'Black Widow', 'Captain America', 'Thor', 'Hulk']

# BEGIN_YOUR_CODE
combined_list = zip(actors,role)
#print(combined_list)
#Tried printing the value as it is - Got the memmory address
#<zip object at 0x000002AB35A57200>
print('Combined list \n',list(combined_list))
# END_YOUR_CODE

#In addition i also tried to test if the list doesnt have equal number of pairs, what would be the result
#Hence i have added 'Dummy' value to my list
# Out:
# Combined list
#  [('Robert Downey Jr.', 'Iron Man'), ('Scarlett Johansson', 'Black Widow'), ('Chris Evans', 'Captain America'), ('Chris Hemsworth', 'Thor'), ('Mark Ruffalo', 'Hulk')]

# %% [markdown]
# 9. Sum function
#
# Modify the given function to compute and return the sum of squares of two integer values a and b.
# For example, for a with value 3 and b with value 4 it should return 25 (9+16).

# %%
def add(a: int, b: int) -> int:

    # BEGIN_YOUR_CODE
    sum_a = a*a
    sum_b = b*b
    result = sum_a+sum_b
    return result
    #raise Exception("Not implemented yet")

    # END_YOUR_CODE

# %% [markdown]
# We defined ```add_test``` to test your ```add``` function. For this function we ```import random``` library. This is a very commonly used package that helps to generate random values. For example:
#
# ``` python
# random.randint(0, 100) #Returns any random integer in range [0, 100]
# ```

# %%
import random

def add_test():
    a = random.randint(0, 9)
    b = random.randint(0, 9)
    result = add(a, b)

    return('Value of a is {0}, value of b is {1}, and their sum of squares is {2}.'.format(a, b,result))

# %%
# Here we call our function 'add_test' to test your add function with random values
if __name__ == '__main__':
   print(add_test())
# Out:
# Value of a is 7, value of b is 3, and their sum of squares is 58.

# %% [markdown]
# In this part we also explore one of the most commonly used package - Numpy. You can refer to the [Official NumPy Guide](https://numpy.org/doc/stable/).

# %% [markdown]
# 10. Import the NumPy package

# %%
# BEGIN_YOUR_CODE
import numpy as np
# END_YOUR_CODE

# %% [markdown]
# 11. Random integers
#
# Create a function that uses the NumPy library to generate an array of 15 random integers.
# The integers should be in the range [0, 90], both inclusive.
# Print the results.
#
# Example Output:
# [0 25 76 14  3  2 49 83  9 42 50 11 36 7 81]

# %%
# BEGIN_YOUR_CODE
import numpy as np
import random

val = np.random.randint(0,91,size=15)
print(val)
# END_YOUR_CODE
#Ouput
#[61  7 88 20 29 84 83 63 24 57 34 77 90 20 84]
# Out:
# [78 38 78 42 74  2 22 44 90 34 74 90 74 41 14]

# %% [markdown]
# 12. Slicing
#
# Slice the above array and extract the first 3 elements, the last 3 elements, and all elements that are left in the middle.

# %%
# BEGIN_YOUR_CODE
first_two = val[:3]
#print(first_two)
'''
Previous code
last_two = val[14:11:-1]
'''
last_two = val[-3:]
#print(last_two)
'''
Previous code
middle = val[3:12]
'''
middle = val[3:-3]
#print(middle)
# END_YOUR_CODE
print('The first 3 elements are {0} \nThe last 3 elements are {1} \nElements in the middle are {2}.'.format(first_two, last_two, middle))
# Out:
# The first 3 elements are [78 38 78]
# The last 3 elements are [74 41 14]
# Elements in the middle are [42 74  2 22 44 90 34 74 90].

# %% [markdown]
# 13. Split an array
#
# For the above list 'array' split the list into 5 equal parts and print it
#
# Output format will be as follows : [array([1,2,3]), array([4,5,6]), array([7,8,9]), array([10,11,12]), array([13,14,15])]
#
# Use built-in function from NumPy to split array

# %%
# BEGIN_YOUR_CODE
#Considering taking the above code as input
print(np.split(val,5))
#When printed this file on vs code(.py), was getting the dtype along with the results, hence checked
# on converting the numpy array to list and then printing
#[array([80, 48, 77], dtype=int32), array([60, 18, 21], dtype=int32), array([56, 69, 48], dtype=int32), array([21, 35, 38], dtype=int32), array([87, 76, 78], dtype=int32)]
valnew = val.tolist()
print(np.array_split(valnew,5))
#print(list(array))
# END_YOUR_CODE
# Out:
# [array([30, 10, 28]), array([16, 49, 24]), array([82, 44, 58]), array([30, 13, 13]), array([85, 53, 29])]
# [array([30, 10, 28]), array([16, 49, 24]), array([82, 44, 58]), array([30, 13, 13]), array([85, 53, 29])]

# %% [markdown]
# 14. Arrays
#
# - Generate two arrays, 'array_a' and 'array_b', each containing 10 randomly selected integers from the range [1, 20] (both inclusive).
# - Print both arrays
# - Use a built-in NumPy function to find the unique elements in 'array_a' and store them in the variable 'unique_elements'.
# - Use a built-in NumPy function to find the common elements shared by 'array_a' and 'array_b' and store them in the variable 'common_elements'.
# - Use a built-in NumPy function to find the union of 'array_a' and 'array_b' and store them in the variable 'union_of_two_arrays'
# - Print 'unique_elements', 'common_elements', and 'union_of_two_arrays'

# %%
array_a = np.random.randint(1,21,size=15)
array_b = np.random.randint(1,21,size=15)
print('Array A: ',array_a)
print('Array B: ',array_b)

unique_elements = np.unique(array_a)
print("Unique elements of A: ",unique_elements)

common_elements = np.intersect1d(array_a,array_b)
print("Common elements of A and B: ",common_elements)

union_of_two_arrays = np.union1d(array_a,array_b)
print("Union elements of A and B: " ,union_of_two_arrays)
# END_YOUR_CODE
# Out:
# Array A:  [ 7  3 13  4 17 20 11  4 17 14 15 14  9  4  2]
# Array B:  [17  5  2  4  4  3 16  3  1 20 20 13 20 17 17]
# Unique elements of A:  [ 2  3  4  7  9 11 13 14 15 17 20]
# Common elements of A and B:  [ 2  3  4 13 17 20]
# Union elements of A and B:  [ 1  2  3  4  5  7  9 11 13 14 15 16 17 20]

# %% [markdown]
# 15. Array operations
#
# You have two arrays, array1 and array2, both containing 5 integer values. Perform the following operations using NumPy functions:
# - Calculate the element-wise sum of array1 and array2.
# - Calculate the element-wise difference between array1 and array2.
# - Calculate the element-wise product of array1 and a scalar value of 3.
# - Calculate the mean (average) value of elements in array2.
# - Calculate the minimum value in array1 and maximum value in array2.
#
#
# Provide the resulting arrays and values after each operation.
#
# Expected output:
#
# Element-wise sum: [15 30 45 60 75]
#
# Element-wise difference: [ 5 10 15 20 25]
#
# Element-wise product with scalar: [ 30  60  90 120 150]
#
# Mean of array2: 15.0
#
# Minimum value in array1: 10
#
# Maximum value in array2: 25

# %%
array1 = np.array([10, 20, 30, 40, 50])
array2 = np.array([5, 10, 15, 20, 25])

# BEGIN_YOUR_CODE
resultSum = np.add(array1,array2)
print('Element-wise sum: ',resultSum)

resultDiff = np.subtract(array1,array2)
print('Element-wise difference: ',resultDiff)

productScalar = np.multiply(resultSum,2)
print('Element-wise product with scalar: ',productScalar)

meanArray2 = np.mean(array2)
print('Mean of array2: ',meanArray2)

minValue = np.min(array1)
print('Minimum value in array1: ',minValue)

maxValue = np.max(array2)
print('Maximum value in array2: ',maxValue)
# END_YOUR_CODE
# Out:
# Element-wise sum:  [15 30 45 60 75]
# Element-wise difference:  [ 5 10 15 20 25]
# Element-wise product with scalar:  [ 30  60  90 120 150]
# Mean of array2:  15.0
# Minimum value in array1:  10
# Maximum value in array2:  25

# %% [markdown]
# 16. Changing dimensions
#
# Combine your 1D arrays defined above to a 2D matrix and print its shape. The final output dimension should be 2x5.

# %%
# BEGIN_YOUR_CODE


array1tobeconverted = np.array([array1])
#print(array1tobeconverted)
array2tobeconverted = np.array([array2])

#print(array2tobeconverted)
newarray = np.concatenate((array1tobeconverted,array2tobeconverted))
#print(newarray)
#myarray = np.array([arraytobeadded])
#print('Combined List of Array: ', myarray)
finalarray = np.reshape(newarray,(2,5))
print('New List 2 X 5: \n', finalarray)

# END_YOUR_CODE
# Out:
# New List 2 X 5:
#  [[10 20 30 40 50]
#  [ 5 10 15 20 25]]

# %% [markdown]
# 17. Changing dimensions
#
# Convert a matrix below to 1D array and print the array and its dimension

# %%
A = np.array([[3,4], [5,6], [7,8]])

# BEGIN_YOUR_CODE
#print(A)
array_1d = A.reshape(-1)
print('1D Array : \n',(array_1d))
print('1D Array Shape : ',(array_1d.shape))
# END_YOUR_CODE
# Out:
# 1D Array :
#  [3 4 5 6 7 8]
# 1D Array Shape :  (6,)

# %% [markdown]
# 18. Matrices
#
# - Create two matrices A and B of size 4X6 and 6X4 respectively with random values in range [0 , 1), 0 is inclusive and 1 is exclusive
# - Perform the dot product of matrices A and B
# - Print matrix A, matrix B, and their dot product
# - Print shape of matrix A, shape of matrix B and shape of their dot product.

# %%
# BEGIN_YOUR_CODE
A = np.random.rand(4,6)
B = np.random.rand(6,4)
dot_product = A.dot(B)
# END_YOUR_CODE

print('\nMatrix A is \n{0} \nMatrix B is \n{1}, \nTheir product is \n{2}'.format(A, B, dot_product))

#randomint didnt work on this as randomint gave me all zeros
#hence opted for random.rand which gives values 0(inclusive)
#and 1 exclusive
# Out:
# Matrix A is
# [[0.74065977 0.76924441 0.59387886 0.99136067 0.89593503 0.01738569]
#  [0.57517826 0.24969534 0.52056368 0.35183152 0.3924642  0.68412513]
#  [0.4409245  0.50503511 0.53337199 0.55872986 0.79547246 0.51236025]
#  [0.15146041 0.62995135 0.30327305 0.1965921  0.76649046 0.50880763]]
# Matrix B is
# [[0.62652284 0.25819044 0.74773465 0.94444497]
#  [0.7849456  0.00949293 0.45809558 0.53056154]
#  [0.58776295 0.79034705 0.04007117 0.22839716]
#  [0.47346343 0.06200304 0.78587191 0.85885824]
#  [0.07388031 0.61364241 0.82181976 0.23520169]
#  [0.7430637  0.04694847 0.2821127  0.52728599]],
# Their product is
# [[1.96539893 1.27997139 2.4502862  2.31461509]
#  [1.5662509  0.85706777 1.35735437 1.54980946]
#  [1.69019485 1.08701885 1.81979013 1.74332837]
#  [1.2954078  0.79120477 1.34193693 1.16395241]]

# %% [markdown]
# 19. Matrix scalar multiplication
#
# - Multiply the previously defined matrix A by a scalar value of 7 using the multiply() function.
# - Print a modified matrix A

# %%
# BEGIN_YOUR_CODE
A = np.multiply(A,7)
print('Value of Scalar: \n',A)
# END_YOUR_CODE
# Out:
# Value of Scalar:
#  [[5.18461842 5.38471089 4.15715202 6.93952471 6.27154524 0.12169986]
#  [4.02624781 1.74786739 3.64394577 2.46282064 2.74724942 4.78887591]
#  [3.08647149 3.53524574 3.73360394 3.91110903 5.56830725 3.58652172]
#  [1.06022287 4.40965943 2.12291133 1.3761447  5.36543319 3.56165341]]

# %% [markdown]
# 20. Maximum value
#
# - Use the np.max() function to find the maximum value in each row of matrix A from Question 18.
# - Store the resulting maximum values in the variable 'max_values'.
# - Print out the results
#
# Expected output:
#
# max_values = [row1_max row2_max row3_max row4_max row5_max]

# %%
# BEGIN_YOUR_CODE
max_values = np.max(A,axis=1)
print('Max values: \n',max_values)
# END_YOUR_CODE
# Out:
# Max values:
#  [6.93952471 4.78887591 5.56830725 5.36543319]

# %% [markdown]
# 21. Element-wise multiplication
#
# Define two matrices A (3X4) and B (3X4) with random integer values in range [0, 9], both inclusive.
#
# Perform element-wise addition, subtraction and multiplication of Matrices A and B

# %%
# BEGIN_YOUR_CODE
A = np.random.randint(0,10,size=(3,4))
B = np.random.randint(0,10,size=(3,4))
addition = np.add(A,B)
subtraction = np.subtract(A,B)
multiplication = np.multiply(A,B)
# END_YOUR_CODE

print('\nMatrix A is \n{0} \nMatrix B is \n{1}'.format(A, B))
print('\nTheir element-wise addition is \n{0}'.format(addition))
print('\nTheir element-wise subtraction is \n{0}'.format(subtraction))
print('\nTheir element-wise multiplication is \n{0}'.format(multiplication))
# Out:
# Matrix A is
# [[8 8 8 3]
#  [6 6 9 6]
#  [4 5 0 8]]
# Matrix B is
# [[0 9 2 4]
#  [3 6 6 7]
#  [5 6 5 4]]
#
# Their element-wise addition is
# [[ 8 17 10  7]
#  [ 9 12 15 13]
#  [ 9 11  5 12]]
#
# Their element-wise subtraction is
# [[ 8 -1  6 -1]
#  [ 3  0  3 -1]
#  [-1 -1 -5  4]]
#
# Their element-wise multiplication is
# [[ 0 72 16 12]
#  [18 36 54 42]
#  [20 30  0 32]]

# %% [markdown]
# <a id='part2'></a>
# ## Part 2: Algorithms [10 Points]
#
# > **Academic Integrity Reminder:**
# > Do not use AI chat, auto-generated solutions for these exercises or your friends' solutions. These are designed to ensure you can implement simple but critical logic. Understanding how to translate a formula into code is an important skill to have.

# %% [markdown]
# ### Euclidian Distance
#
# Let point $p$ have Cartesian coordinates $(p_1,p_2)$ and let point $q$ have coordinates $(q_1,q_2)$. Then the distance between $p$ and $q$ is given by:
#     $d(p,q) = \sqrt{(q_1-p_1)^2 + (q_2-p_2)^2}$.</math>

# %% [markdown]
# 1. Euclidean distance
# Using numpy library return the Euclidean distance between two locations, where the locations are pairs of numbers (e.g., (3, 5))

# %%
def euclidean_distance(loc1: int, loc2: int) -> float:

    # BEGIN_YOUR_CODE

    diff2 = loc2[1]-loc1[1] #(y2-y1)
   #print(diff2)
    sq2 = np.square(diff2)
    diff1 = loc2[0]-loc1[0] #(x2-x1)
    #print(diff1)
    sq1 = np.square(diff1)
    sq3 = sq1 + sq2
    squareDistance = np.sqrt(sq3)
    return float(squareDistance)
    #raise Exception("Not implemented yet")

    # END_YOUR_CODE

# %%
def euclidean_distance_test():
    random.seed(42)
    for _ in range(10):
        x1 = random.randint(0, 10)
        x2 = random.randint(0, 10)
        y1 = random.randint(0, 10)
        y2 = random.randint(0, 10)
        dist = euclidean_distance((x1, x2), (y1, y2))
    return('Loc1 is ({0}, {1}), loc2 is ({2}, {3}). Euclidian disctance is {4}.'.format(x1, x2, y1, y2, dist))

# %%
if __name__ == '__main__':
    print(euclidean_distance_test())
# Out:
# Loc1 is (3, 5), loc2 is (1, 1). Euclidian disctance is 4.47213595499958.

# %% [markdown]
# ### String Operations

# %% [markdown]
# 2. Alphabetically first word
#
# Given a string, lowercase all the elements, then sort our all words in the alphabetical order and return the word that comes first, lexicographically.
#
# If the input text is an empty string, return an empty string or throw an error.
#
# Reflection: Why do we lowercase strings before comparison?

# %%
def first_word(text: str) -> str:


    # BEGIN_YOUR_CODE
    words = text.lower()
    print(words)
    splitwords = words.split()
    print(splitwords)
    sorted_words = sorted(splitwords)
    #print(neww)
    #print(words.sort)
    return str(sorted_words[0])
    #raise Exception("Not implemented yet")

    # END_YOUR_CODE

# %%
''' The output for following test cases will be as follows 'to', 'class', 'decisions', 'cat'
'''

def first_word_test():
    result0 = first_word('WelCome tO Ub')
    result1 = first_word('CSE574 IntRo to ML cLasS')
    result2 = first_word('SequenCes of DeCiSions')
    result3 = first_word('Wolf, Panther, Leopard, Dog, Cat')
    return result0, result1, result2, result3

# %%
if __name__ == '__main__':
    print(first_word_test())
# Out:
# welcome to ub
# ['welcome', 'to', 'ub']
# cse574 intro to ml class
# ['cse574', 'intro', 'to', 'ml', 'class']
# sequences of decisions
# ['sequences', 'of', 'decisions']
# wolf, panther, leopard, dog, cat
# ['wolf,', 'panther,', 'leopard,', 'dog,', 'cat']
# ('to', 'class', 'decisions', 'cat')

# %% [markdown]
# ## Load from Drive*
#
# *If you are using Goolge Colab, uncomment the following piece of code and verify the file using the command, if you can see your file ```penguins.csv``` you are good to go.

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ..
# %cd /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# /
# /content/drive/MyDrive

# %% [markdown]
# <a id='part3'></a>
# ##  Part 3: Pandas Basics (Penguins) [20 Points]
#
# > **Academic Integrity Reminder:**
# > Do not use AI chat, auto-generated solutions for these exercises or your friends' solutions. The goal here is to build confidence working with real dataframes. Comment on what each operation does, and reflect on why you chose it.
#
#
# Some important resources:
#
# - [A Pandas guide](https://pandas.pydata.org/docs/user_guide/index.html) covers fundamental information about the package
#
# ### Penguin dataset
# In this section we will explore with you Palmer Archipelago (Antarctica) penguin dataset. It contains three penguin species and includes measurements of bill length, bill depth, flipper length and body mass. Overall, we are provided with 344 data samples.
#
# The dataset consists of 7 columns:
# - species: penguin species (Chinstrap, Adélie, or Gentoo)
# - culmen_length_mm: culmen length (mm)
# - culmen_depth_mm: culmen depth (mm)
# - flipper_length_mm: flipper length (mm)
# - body_mass_g: body mass (g)
# - island: island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# - gender: penguin gender (female, male)
#
# #### What are culmen length & depth?
# The culmen is "the upper ridge of a bird's beak"
#
# [Culmen length & depth Image](https://allisonhorst.github.io/palmerpenguins/reference/figures/culmen_depth.png)
#
#
# #### What are flippers?
# Penguins wings are called flippers. They are flat, thin, and broad with a long, tapered shape and a blunt, rounded tip.
#
# [Penguins Body Parts Image](https://buffalo.box.com/s/58n5prv8ehb9ln2n7yv5fm2zehwuabsh)

# %% [markdown]
# 1. Import Pandas

# %%
# BEGIN_YOUR_CODE
import pandas as pd
# END_YOUR_CODE

# %% [markdown]
# 2. Load the Penguins dataset into a DataFrame
#
# - Use the provided penguins CSV
# - Assign it to `df`.
# - Show the first 5 rows.

# %%
# BEGIN_YOUR_CODE
df = pd.read_csv('penguins.csv' )
df.head(5)

# END_YOUR_CODE
# Out:
#   species     island  bill_length_mm  ...  body_mass_g  gender  year
# 0  Adelie  Torgersen            39.1  ...       3750.0    male  2007
# 1  Adelie  Torgersen            39.5  ...       3800.0  female  2007
# 2  Adelie  Torgersen            40.3  ...       3250.0  female  2007
# 3  Adelie  Torgersen             NaN  ...          NaN     NaN  2007
# 4  Adelie  Torgersen            36.7  ...       3450.0  female  2007
#
# [5 rows x 8 columns]

# %% [markdown]
# 3. Basic dataset profile
#
# - Show `df.info()` and `df.describe()` for numerical columns.
# - For categorical columns (`species`, `island`, `gender`), show `value_counts()`.
#
# Add 1-2 sentences (as a Python comment) about anything you find surprising or potentially problematic with the dataset.
#
# Reflection: Which variable has the highest spread? Why could that matter in ML?

# %%
# BEGIN_YOUR_CODE
df.info()
df.describe() #numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   gender             333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB
#        bill_length_mm  bill_depth_mm  ...  body_mass_g         year
# count      342.000000     342.000000  ...   342.000000   344.000000
# mean        43.921930      17.151170  ...  4201.754386  2008.029070
# std          5.459584       1.974793  ...   801.954536     0.818356
# min         32.100000      13.100000  ...  2700.000000  2007.000000
# 25%         39.225000      15.600000  ...  3550.000000  2007.000000
# 50%         44.450000      17.300000  ...  4050.000000  2008.000000
# 75%         48.500000      18.700000  ...  4750.000000  2009.000000
# max         59.600000      21.500000  ...  6300.000000  2009.000000
#
# [8 rows x 5 columns]

# %%
#df.value_counts('species')
#df.value_counts('island')
#df.value_counts('gender')
print(df[['species', 'island','gender']].apply(pd.Series.value_counts))
# END_YOUR_CODE
'''
I found that for the given dataset we have the year included in the dataset which seems irrelevant as it does not give
a clear picture on what exactly is it mentioning. Not sure if thats the year the stats were made or were the penguins born
'''

#Reflection: Which variable has the highest spread? Why could that matter in ML?
'''
Ans-> The Highest spread that i feel in this dataset(penguins) would be of body_mass_g type , as the standard deviation is very large for this column
and it could possibly help us explore the model even better , since now the SD (standard deviation) is pretty
high for this model, we can say that per row consisting this body mass would be different and to find the interpretation would be challenging
'''
# Out:
#            species  island  gender
# Adelie       152.0     NaN     NaN
# Biscoe         NaN   168.0     NaN
# Chinstrap     68.0     NaN     NaN
# Dream          NaN   124.0     NaN
# Gentoo       124.0     NaN     NaN
# Torgersen      NaN    52.0     NaN
# female         NaN     NaN   165.0
# male           NaN     NaN   168.0
# '\nAns-> The Highest spread that i feel in this dataset(penguins) would be of body_mass_g type , as the standard deviation is very large for this column\nand it could possibly help us explore the model even better , since now the SD (standard deviation) is pretty\nhigh for this model, we can say that per row consisting this body mass would be different and to find the interpretation would be challenging \n'

# %% [markdown]
# 4. Data cleaning: handle missing values
#
# - Report missing counts per column (sorted descending).
# - Create `cleaned_df` by removing rows with missing values in these key columns:
#   `['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'species', 'gender']`.
# - Print the shapes of `df` and `cleaned_df`.
#
# Reflection: Why might dropping rows be acceptable in this dataset but not in medical records?

# %%
# BEGIN_YOUR_CODE
missingcounts = df.isnull().sum()
#print('Missing Count per column: \n',missingcounts.sort_values(ascending=False))

#--------------

cleaned_df = df

#print('Cleaned DataSet\n',cleaned_df.head(5))

cleaned_df = cleaned_df.drop('year',axis=1)
cleaned_df = cleaned_df.dropna()

print('Shapes of DF: \n',type(df))
print('Shapes of Cleaned DF: \n',type(cleaned_df))
#print('Cleaned dataset after dropping Year column and Making NAN columsn as 0 \n',cleaned_df.head(5))
# END_YOUR_CODE
'''
Reflection: Why might dropping rows be acceptable in this dataset but not in medical records?

Ans -> In medical record each record inserted in the row would be unique to a particualar person.
We can definetly say that every row constitutes to prediction of ML model in future
however for penguins dataset since many columns are NAN, we can still work on the other present data
as our model will be able to figure out after cleaning the dirty rows
'''
# Out:
# Shapes of DF:
#  <class 'pandas.core.frame.DataFrame'>
# Shapes of Cleaned DF:
#  <class 'pandas.core.frame.DataFrame'>
# '\nReflection: Why might dropping rows be acceptable in this dataset but not in medical records?\n\nAns -> In medical record each record inserted in the row would be unique to a particualar person.\nWe can definetly say that every row constitutes to prediction of ML model in future\nhowever for penguins dataset since many columns are NAN, we can still work on the other present data\nas our model will be able to figure out after cleaning the dirty rows\n'

# %% [markdown]
# 5. Create 3 derived features
#
# From `cleaned_df`, create:
# - `body_mass_kg` = `body_mass_g` / 1000
# - `bill_area_mm2` = `bill_length_mm` × `bill_depth_mm`
# - Create an additional feature of your own choice and explain why you picked it.
#
# Show the first 5 rows of these new columns.
#
# Reflection: Which of these new features might help a model separate species?

# %%
# BEGIN_YOUR_CODE
cleaned_df['body_mass_kg'] = df['body_mass_g']/1000
print(cleaned_df.head(5))

cleaned_df['bill_area_mm2'] = df['bill_length_mm']*df['bill_depth_mm']
print(cleaned_df.head(5))


cleaned_df['total_area'] = cleaned_df['bill_area_mm2']*df['flipper_length_mm']
print(cleaned_df.head(5))

# END_YOUR_CODE

'''
Reflection: Which of these new features might help a model separate species?

Ans -> Bill Area would be a good feature to help model separate species , gives a lot about
the dimensions of the penguin

'''
# Out:
#   species     island  bill_length_mm  ...  body_mass_kg  bill_area_mm2  total_area
# 0  Adelie  Torgersen            39.1  ...          3.75         731.17   132341.77
# 1  Adelie  Torgersen            39.5  ...          3.80         687.30   127837.80
# 2  Adelie  Torgersen            40.3  ...          3.25         725.40   141453.00
# 4  Adelie  Torgersen            36.7  ...          3.45         708.31   136703.83
# 5  Adelie  Torgersen            39.3  ...          3.65         809.58   153820.20
#
# [5 rows x 10 columns]
#   species     island  bill_length_mm  ...  body_mass_kg  bill_area_mm2  total_area
# 0  Adelie  Torgersen            39.1  ...          3.75         731.17   132341.77
# 1  Adelie  Torgersen            39.5  ...          3.80         687.30   127837.80
# 2  Adelie  Torgersen            40.3  ...          3.25         725.40   141453.00
# 4  Adelie  Torgersen            36.7  ...          3.45         708.31   136703.83
# 5  Adelie  Torgersen            39.3  ...          3.65         809.58   153820.20
#
# [5 rows x 10 columns]
#   species     island  bill_length_mm  ...  body_mass_kg  bill_area_mm2  total_area
# 0  Adelie  Torgersen            39.1  ...          3.75         731.17   132341.77
# 1  Adelie  Torgersen            39.5  ...          3.80         687.30   127837.80
# 2  Adelie  Torgersen            40.3  ...          3.25         725.40   141453.00
# 4  Adelie  Torgersen            36.7  ...          3.45         708.31   136703.83
# 5  Adelie  Torgersen            39.3  ...          3.65         809.58   153820.20
#
# [5 rows x 10 columns]
# '\nReflection: Which of these new features might help a model separate species?\n\nAns -> Bill Area would be a good feature to help model separate species , gives a lot about\nthe dimensions of the penguin\n\n'

# %% [markdown]
# 6. Groupby + aggregate
#
# Compute the mean and standard deviation of `body_mass_g`, `flipper_length_mm`, and `bill_length_mm` grouped by `species` and `island`.
# Sort the result by `species` then `island`. Write brief observations as a Python comment.
#
# Reflection: What trends do you see between species and islands?

# %%
# BEGIN_YOUR_CODE

'''
selected_columns = ['body_mass_g','flipper_length_mm','bill_length_mm']

resultTobeSorted = cleaned_df.groupby(['species','island']).agg(
    selected_columns.mean()
)'''

resultTobeSorted = cleaned_df.groupby(['species','island']).agg(
    body_mass_g_mean=('body_mass_g','mean'),
    body_mass_g_std =('body_mass_g','std'),
    flipper_length_mm_mean=('flipper_length_mm','mean'),
    flipper_length_mm_std=('flipper_length_mm','std'),
    bill_length_mm_mean = ('bill_length_mm','mean'),
    bill_length_mm_std = ('bill_length_mm','std')
)


print(resultTobeSorted.sort_values(by=['species','island']))

# END_YOUR_CODE

'''
Reflection: What trends do you see between species and islands?

Ans -> Theere are at max 3 species and 3 islands, however most of the penguins
can be seen in Adelie (3), whereas the rest 2 islands have one specific type of
specie only
'''
# Out:
#                      body_mass_g_mean  ...  bill_length_mm_std
# species   island                       ...
# Adelie    Biscoe          3709.659091  ...            2.480916
#           Dream           3701.363636  ...            2.484276
#           Torgersen       3708.510638  ...            3.028097
# Chinstrap Dream           3733.088235  ...            3.339256
# Gentoo    Biscoe          5092.436975  ...            3.106116
#
# [5 rows x 6 columns]
# '\nReflection: What trends do you see between species and islands?\n\nAns -> Theere are at max 3 species and 3 islands, however most of the penguins \ncan be seen in Adelie (3), whereas the rest 2 islands have one specific type of \nspecie only\n'

# %% [markdown]
# 7. Per-group filtering (Top-N)
#
# For each `species`, return the top 2 heaviest penguins (by `body_mass_g`). Show columns: `species, island, gender, body_mass_g`.
# (If ties occur, keep any 2 per species.)
#
# Reflection: Why might top-N analysis be useful when summarizing groups?

# %%
# BEGIN_YOUR_CODE

#print(cleaned_df.info())
n=2

#top_n_value_penguins = cleaned_df.groupby('species')['body_mass_g'].nlargest(n)
#print(top_n_value_penguins)

#Was not able to print the desired columns with this above approach and checked further
#what can be done to print the columns , also removing the species from the desired output

top_n_value =cleaned_df.groupby('species').apply(lambda x: x.nlargest(n,'body_mass_g'))
#print(top_n_value)

#Dropping multiindex after group by so that we could get all the columns listed
top_n_value = top_n_value.reset_index(drop=True)

#print('After Resetting index \n',top_n_value)

top_n_value = top_n_value[['species','island','gender','body_mass_g']]

print('After Converting to desired Columns \n',top_n_value)
#print(top_n_value)
#print(top_penguins)
#print(type(top_n_value))
#print(cleaned_df[['species','island','gender','body_mass_g']])


# END_YOUR_CODE

'''
Reflection: Why might top-N analysis be useful when summarizing groups?

Ans -> It gives entire row details and filters on the largest/smallest value for
a specific columns as needed , hence top-N analysis is useful
'''
# Out:
# After Converting to desired Columns
#       species  island gender  body_mass_g
# 0     Adelie  Biscoe   male       4775.0
# 1     Adelie  Biscoe   male       4725.0
# 2  Chinstrap   Dream   male       4800.0
# 3  Chinstrap   Dream   male       4550.0
# 4     Gentoo  Biscoe   male       6300.0
# 5     Gentoo  Biscoe   male       6050.0
# /tmp/ipython-input-3831750245.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_n_value =cleaned_df.groupby('species').apply(lambda x: x.nlargest(n,'body_mass_g'))
# '\nReflection: Why might top-N analysis be useful when summarizing groups?\n\nAns -> It gives entire row details and filters on the largest/smallest value for\na specific columns as needed , hence top-N analysis is useful\n'

# %% [markdown]
# 8. Convert to categorical
#
# Ensure `species`, `island`, and `gender` are of `category` dtype in `cleaned_df`.
# Show their `.dtype`.

# %%
# BEGIN_YOUR_CODE
#print('Before: \n', cleaned_df.info())

cleaned_df['species'] = cleaned_df[['species']].astype('category')
cleaned_df['island'] = cleaned_df['island'].astype('category')
cleaned_df['gender'] = cleaned_df['gender'].astype('category')

print('Dtype: \n',type(cleaned_df.dtypes))

#cleaned_df.info()
# END_YOUR_CODE
# Out:
# Dtype:
#  <class 'pandas.core.series.Series'>

# %% [markdown]
# 9. Normalization
#
# Create a normalized version of `flipper_length_mm` called `flipper_length_z` using the mean and std from `cleaned_df`.
# Verify it has mean ≈ 0 and std ≈ 1 (print both).
#
# Reflection: Why is normalization important before training machine learning models?

# %%
# BEGIN_YOUR_CODE
flipper_length_mm_mean = cleaned_df['flipper_length_mm'].mean()
flipper_length_mm_stdev = cleaned_df['flipper_length_mm'].std()

cleaned_df['flipper_length_z'] = (cleaned_df['flipper_length_mm']-flipper_length_mm_mean)/flipper_length_mm_stdev

#cleaned_df.info()

newColumnMeanVal = cleaned_df['flipper_length_z'].mean()
print('Mean: ',newColumnMeanVal)
#2.13376196924955e-16 is more or less equivalent to zero hence printing this
newColumnSTDVal2 = cleaned_df['flipper_length_z'].std()
print('\nStandard deviation: ',newColumnSTDVal2)


# END_YOUR_CODE

'''
Reflection: Why is normalization important before training machine learning models?

Ans -> Mainly it would be so that it could treat all the values within a particuale range
and does not rely on values from the column which could not be accurate, a kind of scaling approach
can be called as normalisation.
'''
# Out:
# Mean:  2.13376196924955e-16
#
# Standard deviation:  1.0000000000000002
# '\nReflection: Why is normalization important before training machine learning models?\n\nAns -> Mainly it would be so that it could treat all the values within a particuale range\nand does not rely on values from the column which could not be accurate, a kind of scaling approach \ncan be called as normalisation.\n'

# %% [markdown]
# 10. Save your cleaned data
#
# Save `cleaned_df` to `penguins_cleaned.csv`.

# %%
# BEGIN_YOUR_CODE

cleaned_df.to_csv('penguins_cleaned.csv')
# END_YOUR_CODE

# %% [markdown]
# <a id='part4'></a>
# ##  Part 4: Matplotlib Basics (Penguins) [20 Points]
#
# You will create informative plots from the `cleaned_df` produced in Part 3.
#
# > **Academic Integrity Reminder:**
# > Do not use AI chat, auto-generated solutions for these exercises or your friends' solutions. The goal is to build your own plotting fluency. Add comments explaining choices (e.g., why a scatter is preferable to a line plot for unordered observations).
#
# > **Tip:** Always label axes, add a title/legend when appropriate, and save figures as both **PNG and PDF** with `dpi=300` and `bbox_inches='tight'`.

# %% [markdown]
# 1. Import Matplotlib

# %%
# BEGIN_YOUR_CODE
import matplotlib.pyplot as plt

# END_YOUR_CODE

# %% [markdown]
# 2. Scatter *vs* Line on the same data
#
# Plot `flipper_length_mm` (x) vs `body_mass_g` (y):
# - In one figure, draw a **scatter plot** of all points.
# - On the **same axes**, add a **line plot** of the *species-wise rolling mean* (sorted by `flipper_length_mm`, window=5) for one chosen species.
# - Add labels, legend, and title. Briefly comment (in code) on why line plots can be misleading for unordered observations.
#
# Save as `part4_task2_scatter_line.png` and `.pdf`.
#
# Reflection: Why can line plots be misleading for unordered data?

# %%
# BEGIN_YOUR_CODE
plt.scatter(cleaned_df['flipper_length_mm'],cleaned_df['body_mass_g'],color='yellow')

specie_to_be_chosen = cleaned_df[cleaned_df['species']=='Adelie'].sort_values(by=['flipper_length_mm'])
#print(specie_to_be_chosen)

specie_to_be_chosen['rolling'] = specie_to_be_chosen['body_mass_g'].rolling(window=5).mean()
#print(specie_to_be_chosen)

plt.plot(specie_to_be_chosen['flipper_length_mm'],specie_to_be_chosen['rolling'])

plt.title('Scatter Plot of Flippers vs Body Mass')
plt.xlabel('Flipper Length(mm)')
plt.ylabel('Body Mass(g)')


plt.legend(labels=['Scatter', 'Line'])
plt.show()

plt.savefig('part4_task2_scatter_line.png',dpi=300,bbox_inches='tight')
plt.savefig('part4_task2_scatter_line.pdf',dpi=300,bbox_inches='tight')



# END_YOUR_CODE

'''
Reflection: Why can line plots be misleading for unordered data?

Ans -> Line plots give the accurate measure of how the data is distributed
wrt x and y (lets say these are two terms) ,  but for unordered data, these points
wont be continuous or wont show a relation between the two , hence scatter is applicable
for unordered data
'''

# %% [markdown]
# 3. Overlay with different scales (dual y-axes)
#
# Using a subset of `cleaned_df` for a single species (choose any), sort by `bill_length_mm` and plot:
# - `bill_length_mm` on the x-axis
# - `flipper_length_mm` on the **left y-axis** (line)
# - `body_mass_g` on the **right y-axis** (line)
#
# Add axis labels, title, and legends.
# Save as `part4_task3_dual_axis.png` and `.pdf`.
#
# Reflection: What challenge do you see when plotting variables with different scales?

# %%
# BEGIN_YOUR_CODE
subsetOfCleaned_df = cleaned_df

ans = input('Enter the specie you wish to see: \n')
print('Okay great you wish to see for : ',ans)

subsetOfCleaned_df = cleaned_df[cleaned_df['species']==ans].sort_values(by=['bill_length_mm'])
#print(subsetOfCleaned_df)

fig,ax1 = plt.subplots()

ax1.set_xlabel('X-Axis')
ax1.set_ylabel('Y1-Axis')
ax1.plot(subsetOfCleaned_df['bill_length_mm'], subsetOfCleaned_df['flipper_length_mm'], color = 'yellow',label='Flipperlength')
ax1.legend()
ax2 = ax1.twinx()


ax2.set_ylabel('Y2-Axis')
ax2.plot(subsetOfCleaned_df['bill_length_mm'],subsetOfCleaned_df['body_mass_g'], color = 'blue')
ax2.set_title('Plotting Bill length against Flipper Length and Body Mass')
ax2.legend(labels=['Body Mass'],loc='upper right')

plt.savefig('part4_task3_dual_axis.png', dpi=300,bbox_inches='tight')
plt.savefig('part4_task3_dual_axis.pdf', dpi=300,bbox_inches='tight')

# END_YOUR_CODE

'''
Reflection: What challenge do you see when plotting variables with different scales?

Ans -> Main issue is the visualisation , not able to interpret the yellow data which
got overshadowed by the blue line, becomes bit difficult to get any understanding
from these multiplots
'''
# Out:
# Enter the specie you wish to see:
# Adelie
# Okay great you wish to see for :  Adelie
# '\nReflection: What challenge do you see when plotting variables with different scales?\n\nAns -> Main issue is the visualisation , not able to interpret the yellow data which\ngot overshadowed by the blue line, becomes bit difficult to get any understanding\nfrom these multiplots\n'

# %% [markdown]
# 4. Annotate extremes (max/min)
#
# Create a scatter plot of `flipper_length_mm` vs `body_mass_g` colored by `species` (loop over species and plot each). Annotate the **global max** and **global min** of `body_mass_g` with arrows and text `max`/`min`.
#
# Save as `part4_task4_annotations.png` and `.pdf`.
#
# Reflection: Do you think max/min outliers are errors or natural variation? Why?

# %%
# BEGIN_YOUR_CODE

#Was trying to use the below code to label the colors indicating the species
#species_list_count = cleaned_df.sort_values(by=['body_mass_g'],ascending=False)
#print(species_list_count)

species_list = cleaned_df['species'].unique()
#print('Species List: ',species_list)

for i,species in enumerate(species_list):
  speciesPlotted = cleaned_df[cleaned_df['species'] == species]
  plt.scatter(speciesPlotted['flipper_length_mm'],speciesPlotted['body_mass_g']  )

max_row_body_mass = cleaned_df.loc[cleaned_df['body_mass_g'].idxmax()]
#print(max_row_body_mass)
min_row_body_mass = cleaned_df.loc[cleaned_df['body_mass_g'].idxmin()]
#print(min_row_body_mass)


plt.annotate('Global Max',xy=(max_row_body_mass['flipper_length_mm'],max_row_body_mass['body_mass_g']),arrowprops=dict(arrowstyle='->',color='red'))

plt.annotate('Global Min',xy=(min_row_body_mass['flipper_length_mm'],min_row_body_mass['body_mass_g']),arrowprops=dict(arrowstyle='->',color='red'))

plt.xlabel('Flipper Length')
plt.ylabel('Body Mass')
plt.title('Flipper length vs Body Mass (pointing highest and loweest)')
plt.show()

plt.savefig('part4_task4_annotations.png',dpi=300,bbox_inches='tight')
plt.savefig('part4_task4_annotations.pdf',dpi=300,bbox_inches='tight')
# END_YOUR_CODE

'''
Reflection: Do you think max/min outliers are errors or natural variation? Why?

Ans -> I dont think max/min outliers are errors, they can be natural variation
it wont evr be possible that all the values lie within the same range, some
are bound to cause a variation which can be accepted, but not termed as Errors
'''
# Out:
# '\nReflection: Do you think max/min outliers are errors or natural variation? Why?\n\nAns -> I dont think max/min outliers are errors, they can be natural variation\nit wont evr be possible that all the values lie within the same range, some\nare bound to cause a variation which can be accepted, but not termed as Errors\n'

# %% [markdown]
# 5. Create one extra visualization of your choice that highlights something interesting about the data.

# %%
# BEGIN_YOUR_CODE

plt.scatter(cleaned_df['gender'],cleaned_df['flipper_length_mm'],label='Flip length')

plt.xlabel('Gender')
plt.ylabel('Flipper Length')
plt.title('Indicating  Flip length indicating who has greater length between male and female')
#plt.boxplot(cleaned_df)

plt.legend()
plt.show()


plt.savefig('part4_task5_extravisualisation.png',dpi=300,bbox_inches='tight')
# END_YOUR_CODE

# %% [markdown]
# <a id='part5'></a>
# # Part 5: Sckit-learn Basics [20 Points]
#
# In this part we will use scikit-learn library.
#
# Skit-learn is a commonly used data analysis library. It contains in-build unsupervised and supervised learning algorithms. Check more details here - https://scikit-learn.org/stable/.

# %% [markdown]
# 1. Install and import scikit-learn library

# %%
# BEGIN_YOUR_CODE
import sklearn

# !pip install scikit-learn

# END_YOUR_CODE
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# 2. Prepare your final cleaned Penguins dataset for training
# - Define our X_data = features from the dataset, exept 'Species'. You can select all features or some, it's up to you.
# - Define Y_target = 'Species' column from the dataset
# - Use the train_test_split() function to split the dataset into training and testing sets. Pass the features (X_data) and target (Y_target), set test_size to 0.2 for an 80/20 split
# - Print the shapes of X_train, X_test, Y_train, and Y_test sets

# %%
# BEGIN_YOUR_CODE
#Initialising pandas again , so that incase it gets disconnected i wont have to run from the start :)
import pandas as pd

Modified_df = pd.read_csv('penguins_cleaned.csv')
Y_target = Modified_df['species']
#print(Y_target)
X_data = Modified_df[['island','bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g','gender']]
#print(X_data)

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_data,Y_target,test_size=0.2,random_state=25)

print('Shape X Train: \n',type(X_train))
print('Shape Y Train: \n',type(Y_train))
print('Shape X Test: \n',type(X_test))
print('Shape Y Test: \n',type(Y_test))
#print(Modified_df.head(5))
# END_YOUR_CODE
# Out:
# Shape X Train:
#  <class 'pandas.core.frame.DataFrame'>
# Shape Y Train:
#  <class 'pandas.core.series.Series'>
# Shape X Test:
#  <class 'pandas.core.frame.DataFrame'>
# Shape Y Test:
#  <class 'pandas.core.series.Series'>

# %% [markdown]
# 3. Fit the model
# - Create and fit a logistic regression model to predict the 'Species' of a penguin using all of the other features in the dataset.
# - You can use one hot encoding to encode categorical-based feature ('island' and 'gender') or reuse your code from abouve
# - Create a logistic regression model using LogisticRegression().
# - Fit the model using the training data
# - Make predictions on the testing data using the trained model
# - Print the accuracy score by comparing the predicted values with the actual target values using accuracy_score()
# - Print the parameter values of the logistic regression model using get_params()
#
# You can read more about the inbuild Logistic Regression model here - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
# BEGIN_YOUR_CODE
#Modified_df.info()
from sklearn.linear_model import LogisticRegression


#model = LogisticRegression()
#model.fit(X_train,Y_train)

#The above code gave error since model contains non categorical value, hence now
#i need to use hot encoding

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

categorical_cols = ['island', 'gender']

preprocessing = ColumnTransformer(
    transformers = [('onehotencoded',OneHotEncoder(),categorical_cols)],remainder='passthrough')

X_encodeddata = preprocessing.fit_transform(X_data)
#Was getting 100% Accuracy when i kept the test_size = 0.2
#X_train,X_test,Y_train,Y_test = train_test_split(X_encodeddata,Y_target,test_size=0.2)

X_train,X_test,Y_train,Y_test = train_test_split(X_encodeddata,Y_target,test_size=0.55,random_state=25)

model = LogisticRegression()
model.fit(X_train,Y_train)

Y_dash =model.predict(X_test)
#print(Y_dash)

#Accuracy score
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test, Y_dash)
print('Accuracy: \n',accuracy)

print('Logistic Regression Parameters: \n',model.get_params())
# END_YOUR_CODE
# Out:
# Accuracy:
#  0.9782608695652174
# Logistic Regression Parameters:
#  {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# <a id='part6'></a>
# # Part 6: Optuna Basics [10 Points]
#
# Optuna is a an open-source framework that helps to automatically search best hyperparameters, when training machine learning or deep learning models.
# Check more details here - https://optuna.org/ . In this part we will use optuna framework.
#
# > **Academic Integrity Reminder:**
# > Do not use AI chat, auto-generated solutions for these exercises or your friends' solutions. Optuna is an industry-level tool, often used to find optimal hyperparameteres for neural networks.

# %% [markdown]
# 1. Install and import optuna. You can read more about installation here - https://optuna.org/#installation

# %%
# BEGIN_YOUR_CODE

# !pip install optuna

import optuna
# END_YOUR_CODE

# %% [markdown]
# You can refer code examples on how to use optuna here - https://optuna.org/#code_examples

# %% [markdown]
# 2. Optimize hyperparameters using Optuna
# - Reuse the code from Part 5 for fitting a logistic regression model using scikit-learn
# - Use Optuna to determine the optimal values for two hyperparameters in logistic regression: C and max_iter.
#
#     The aim is to find the hyperparameters that result in the highest accuracy score
#
#     The hyperparameter C should be in the range [0.01, 10], and max_iter should be within the range of [100, 1000]
# - Print the optimal values of C and max_iter and corresponding accuracy score obtained

# %%
# BEGIN_YOUR_CODE
import optuna

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

def objective(trial):

  categorical_cols = ['island', 'gender']

  preprocessing = ColumnTransformer(
  transformers = [('onehotencoded',OneHotEncoder(),categorical_cols)],remainder='passthrough')

  X_encodeddata = preprocessing.fit_transform(X_data)
  #Was getting 100% Accuracy when i kept the test_size = 0.2
  #X_train,X_test,Y_train,Y_test = train_test_split(X_encodeddata,Y_target,test_size=0.2)

  C = trial.suggest_loguniform('C', 0.01, 10)
  max_iter = trial.suggest_int('max_iter',100,1000)

  X_train,X_test,Y_train,Y_test = train_test_split(X_encodeddata,Y_target,test_size=0.55,random_state=25)

  model = LogisticRegression(C=C,max_iter=1000)

  model.fit(X_train,Y_train)

  Y_dash =model.predict(X_test)
  accuracy_val = accuracy_score(Y_test,Y_dash)

  return accuracy_val

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

best_trial = study.best_trial
print(f"Value of C parameter: {best_trial.params['C']}")
print(f"Best Max_iter: {best_trial.params['max_iter']}")
print(f"Highest Accuracy: {best_trial.value}")
# END_YOUR_CODE
# Out:
# [I 2025-09-12 01:52:11,520] A new study created in memory with name: no-name-b0ad65ab-14ea-4976-bf71-b8e11126e191
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:11,718] Trial 0 finished with value: 0.9945652173913043 and parameters: {'C': 0.3426232619019577, 'max_iter': 505}. Best is trial 0 with value: 0.9945652173913043.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:11,927] Trial 1 finished with value: 0.9945652173913043 and parameters: {'C': 0.06339965811895083, 'max_iter': 195}. Best is trial 0 with value: 0.9945652173913043.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:12,144] Trial 2 finished with value: 0.9891304347826086 and parameters: {'C': 0.19652484739068043, 'max_iter': 488}. Best is trial 0 with value: 0.9945652173913043.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:12,388] Trial 3 finished with value: 0.9945652173913043 and parameters: {'C': 0.0407100991643093, 'max_iter': 786}. Best is trial 0 with value: 0.9945652173913043.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:12,596] Trial 4 finished with value: 0.9945652173913043 and parameters: {'C': 7.885729581247906, 'max_iter': 331}. Best is trial 0 with value: 0.9945652173913043.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:12,804] Trial 5 finished with value: 1.0 and parameters: {'C': 5.840760852495872, 'max_iter': 893}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:13,001] Trial 6 finished with value: 0.9728260869565217 and parameters: {'C': 0.01547814599852129, 'max_iter': 433}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:13,222] Trial 7 finished with value: 0.9945652173913043 and parameters: {'C': 0.859573973270619, 'max_iter': 157}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:13,467] Trial 8 finished with value: 0.9728260869565217 and parameters: {'C': 0.014983069602983089, 'max_iter': 932}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:13,679] Trial 9 finished with value: 0.9945652173913043 and parameters: {'C': 8.952245756022704, 'max_iter': 925}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:13,997] Trial 10 finished with value: 0.9945652173913043 and parameters: {'C': 1.9057517219378663, 'max_iter': 712}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:15,105] Trial 11 finished with value: 0.9945652173913043 and parameters: {'C': 1.4600711699073274, 'max_iter': 609}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:16,050] Trial 12 finished with value: 0.9945652173913043 and parameters: {'C': 0.363160522859279, 'max_iter': 654}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:16,682] Trial 13 finished with value: 1.0 and parameters: {'C': 2.666041476231847, 'max_iter': 350}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:17,070] Trial 14 finished with value: 1.0 and parameters: {'C': 4.987346985511538, 'max_iter': 328}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:17,290] Trial 15 finished with value: 0.9945652173913043 and parameters: {'C': 3.264243204164997, 'max_iter': 839}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:17,502] Trial 16 finished with value: 0.9945652173913043 and parameters: {'C': 0.7419200850005163, 'max_iter': 345}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:17,750] Trial 17 finished with value: 1.0 and parameters: {'C': 2.46950500525429, 'max_iter': 249}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:17,996] Trial 18 finished with value: 0.9945652173913043 and parameters: {'C': 4.036900418594197, 'max_iter': 103}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:18,222] Trial 19 finished with value: 1.0 and parameters: {'C': 1.3351007227228022, 'max_iter': 563}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:18,433] Trial 20 finished with value: 1.0 and parameters: {'C': 0.14215328005303404, 'max_iter': 417}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:18,682] Trial 21 finished with value: 0.9945652173913043 and parameters: {'C': 4.9658463811575215, 'max_iter': 297}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:18,892] Trial 22 finished with value: 0.9945652173913043 and parameters: {'C': 9.788726502929258, 'max_iter': 405}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:19,114] Trial 23 finished with value: 0.9945652173913043 and parameters: {'C': 5.0009535976069275, 'max_iter': 249}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:19,332] Trial 24 finished with value: 0.9891304347826086 and parameters: {'C': 0.6773584662154197, 'max_iter': 725}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:19,543] Trial 25 finished with value: 0.9945652173913043 and parameters: {'C': 2.555485774866562, 'max_iter': 988}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:19,791] Trial 26 finished with value: 0.9945652173913043 and parameters: {'C': 5.225873360423326, 'max_iter': 364}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:20,008] Trial 27 finished with value: 0.9945652173913043 and parameters: {'C': 1.149667942597825, 'max_iter': 477}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:20,235] Trial 28 finished with value: 0.9945652173913043 and parameters: {'C': 6.332438641185299, 'max_iter': 578}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:20,457] Trial 29 finished with value: 0.9945652173913043 and parameters: {'C': 0.3418166055854069, 'max_iter': 504}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:20,670] Trial 30 finished with value: 0.9945652173913043 and parameters: {'C': 3.1322934014134765, 'max_iter': 828}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:20,919] Trial 31 finished with value: 0.9945652173913043 and parameters: {'C': 2.2476664413306775, 'max_iter': 253}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:21,142] Trial 32 finished with value: 0.9891304347826086 and parameters: {'C': 2.0601016680764075, 'max_iter': 224}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:21,357] Trial 33 finished with value: 0.9945652173913043 and parameters: {'C': 0.4984367577307861, 'max_iter': 291}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:21,583] Trial 34 finished with value: 1.0 and parameters: {'C': 3.559258608848142, 'max_iter': 173}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:21,828] Trial 35 finished with value: 0.9891304347826086 and parameters: {'C': 0.18303456727714512, 'max_iter': 298}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:22,056] Trial 36 finished with value: 0.9945652173913043 and parameters: {'C': 6.332847980083572, 'max_iter': 103}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:22,279] Trial 37 finished with value: 0.9945652173913043 and parameters: {'C': 0.07563846313585183, 'max_iter': 396}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:22,491] Trial 38 finished with value: 0.9945652173913043 and parameters: {'C': 1.0334319839003836, 'max_iter': 196}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:22,703] Trial 39 finished with value: 0.9945652173913043 and parameters: {'C': 1.7650577542816224, 'max_iter': 441}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:22,951] Trial 40 finished with value: 0.9945652173913043 and parameters: {'C': 8.271794580087588, 'max_iter': 471}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:23,181] Trial 41 finished with value: 0.9945652173913043 and parameters: {'C': 1.2491355958263706, 'max_iter': 535}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:23,409] Trial 42 finished with value: 1.0 and parameters: {'C': 2.6598603454474494, 'max_iter': 357}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:23,637] Trial 43 finished with value: 1.0 and parameters: {'C': 4.120287404588772, 'max_iter': 687}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:23,859] Trial 44 finished with value: 0.9945652173913043 and parameters: {'C': 0.5814146130603751, 'max_iter': 611}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:24,128] Trial 45 finished with value: 0.9945652173913043 and parameters: {'C': 1.4975841490912072, 'max_iter': 773}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:24,362] Trial 46 finished with value: 0.9945652173913043 and parameters: {'C': 6.581482238762211, 'max_iter': 906}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:24,576] Trial 47 finished with value: 0.9945652173913043 and parameters: {'C': 2.944589113909274, 'max_iter': 543}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:24,796] Trial 48 finished with value: 0.9728260869565217 and parameters: {'C': 0.03366209058717429, 'max_iter': 155}. Best is trial 5 with value: 1.0.
# /tmp/ipython-input-396129408.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2025-09-12 01:52:25,073] Trial 49 finished with value: 0.9945652173913043 and parameters: {'C': 0.945222441807628, 'max_iter': 274}. Best is trial 5 with value: 1.0.
# Value of C parameter: 5.840760852495872
# Best Max_iter: 893
# Highest Accuracy: 1.0

# %% [markdown]
# <a id='references'></a>
# ## References Used
#
# **List below all the references you used to complete this assignment, including full links to the online resources**
#
# <font color='red'>Missing references will result in -5 points for the assignmnent. If you haven't used any resources to complete this assignments, just add "None" below</font>

# %% [markdown]
# https://numpy.org/doc/stable/index.html

# %% [markdown]
# https://docs.python.org/3/

# %% [markdown]
# https://www.geeksforgeeks.org/numpy/python-numpy/#

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %% [markdown]
# https://optuna.org/

# %% [markdown]
# https://optuna.readthedocs.io/en/stable/

# %% [markdown]
# https://www.geeksforgeeks.org/pandas/pandas-tutorial/

# %% [markdown]
# **Instructions**:
#
# * Do not copy paste code from the references. You can refer to better understand and then code yourself.
# * Prefer official documentations over other sources, for accurate and standard practices.
# * Do not use ANY kind of AI-based assitants, e.g. ChatGPT, Gemini, intergrate AI into VS Code or any other AI-based tool. This assignment is aiming to strengthen your Python skills. Python is a crucial language in AI and data science, so ensure you're comfortable with its various aspects.
# * Have fun and all the best!
